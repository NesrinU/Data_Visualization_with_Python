# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Use below dataframe for plots**

# %%
income = [100, 80, 150, 48, 52, 69, 88]
expense = [30, 100, 100, 20, 75, 50, 28]
index = ['A', 'B', 'C','D', 'E', 'F', 'G']
df = pd.DataFrame({'income': income,'expense': expense}, index=index)
df.head()
# Out:
#    income  expense
# A     100       30
# B      80      100
# C     150      100
# D      48       20
# E      52       75

# %% [markdown]
# **Bar plots**

# %% [markdown]
# # 1. Set darkgrid style from seaborn

# %%
# CODE HERE
sns.set_style("darkgrid")

# %% [markdown]
# # 2. Make a bar plot

# %%
fig, ax = plt.subplots(figsize=(6, 4))

p = np.arange(len(index))
width = 0.25

ax.bar(p - width/2, income, width, label="income")
ax.bar(p + width/2, expense,           width, label="expense")

ax.set_xticks(p)
ax.set_xticklabels(index)

plt.legend()
plt.show()

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df[['income', 'expense']].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = "bar", figsize =(6,4))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3. Stack the bars

# %%
# CODE HERE
fig, ax = plt.subplots(figsize= (6,4))

ax.bar(index, income, label= 'income')
ax.bar(index, expense , label='expense' )

plt.legend();

# %%
df.plot.bar(stacked= True);

# %%
df[['income', 'expense']].plot(kind='bar', stacked= True
                              )
# Out:
# <AxesSubplot:>

# %%
ax = df.plot.bar(stacked = True)
sns.set_style(style = "darkgrid")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 4. Rotate the labels and set figsize

# %%
df[['income', 'expense']].plot(kind='bar', stacked= True, figsize=(9,6), rot= 0)
# Out:
# <AxesSubplot:>

# %%
df.plot.bar(stacked=True, rot = 0, figsize=(9,6));

# %% [markdown]
# # 5. Replace the labels by "Game-1", "Game-2", "Game-3", "Game-4", "Game-5", "Game-6", "Game-7"

# %%
# df= df.set_index( ["Game-1", "Game-2", "Game-3", "Game-4", "Game-5", "Game-6", "Game-7"] )

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G'], dtype='object')

# %%
# CODE HERE

df.index= ["Game-1", "Game-2", "Game-3", "Game-4", "Game-5", "Game-6", "Game-7"]

# %%
df.index
# Out:
# Index(['Game-1', 'Game-2', 'Game-3', 'Game-4', 'Game-5', 'Game-6', 'Game-7'], dtype='object')

# %%
index=['Game-1', 'Game-2', 'Game-3', 'Game-4', 'Game-5', 'Game-6', 'Game-7']

# %% [markdown]
# # 6. Unstuck the bars, annotate the hight of the bars on top of them

# %%
# CODE HERE

# %%
fig, ax = plt.subplots(figsize=(9, 6))

p = np.arange(len(index))
width = 0.25

ax.bar(p - width/2, income, width, label="income")
ax.bar(p + width/2, expense,           width, label="expense")

ax.set_xticks(p)
ax.set_xticklabels(index)

for bar in ax.patches :
    ax.annotate(bar.get_height(), (bar.get_x(), bar.get_height()+0.8))

plt.legend()
plt.show()

# %%
fig, ax=plt.subplots(figsize=(9,6))
df.plot(kind='bar', stacked=True, ax=ax, rot=0)
plt.xticks(np.arange(7), ['Game-1', 'Game-2', 'Game-3', 'Game-4', 'Game-5', 'Game-6', 'Game-7']);

# %% [markdown]
# **histograms**

# %%
tips=sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 6. Histogram of the total_bill column

# %%
# CODE HERE
sns.histplot(x= 'total_bill', data= tips);

# %%
plt.hist(tips.total_bill)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **lineplots**

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 7. Plot the avg tip by size  (lineplot)

# %%
df1= tips.groupby('size')['tip'].mean()
df1
# Out:
# size
# 1    1.437500
# 2    2.582308
# 3    3.393158
# 4    4.135405
# 5    4.028000
# 6    5.225000
# Name: tip, dtype: float64

# %%
df1.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6], dtype='int64', name='size')

# %%
df1.values
# Out:
# array([1.4375    , 2.58230769, 3.39315789, 4.13540541, 4.028     ,
#        5.225     ])

# %%
# CODE HERE
fig, ax = plt.subplots()
ax.plot(df1.index, df1.values)
ax.set_xlabel("size");

# %%
tips.groupby('size')['tip'].mean().plot()
# Out:
# <AxesSubplot:xlabel='size'>

# %%
sns.lineplot(tips['size'],tips.tip,err_style=None)
plt.ylabel('');

# %%
sns.lineplot(x= 'size', y= 'tip',data=tips, ci=False)
plt.ylabel(None);

# %% [markdown]
# # 8.Set the linestyle as "--"

# %%
# CODE HERE
fig, ax = plt.subplots()
ax.plot(df1.index, df1.values, linestyle='--')
ax.set_xlabel("size");

# %%
sns.lineplot(x= 'size', y= 'tip',data=tips, ci=False, ls="--")
plt.ylabel(None);

# %%
tips.groupby('size')['tip'].mean().plot(ls="--")
# Out:
# <AxesSubplot:xlabel='size'>

# %% [markdown]
# **Scatter Plots**

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 9. Make a scatter plot between tip and total_bill

# %%
# CODE HERE

plt.scatter(tips['tip'], tips['total_bill'])
plt.xlabel('Tip')
plt.ylabel('Total_bill');

# %%
tips.plot.scatter(x= 'tip', y= 'total_bill');

# %%
sns.scatterplot(x ='tip', y= 'total_bill', data=tips);

# %% [markdown]
# # 10. Set an additional dimension using size column

# %%
# CODE HERE
#fig, ax=plt.subplots(figsize=(6,4))
plt.scatter(x='tip', y='total_bill', data=tips, alpha = .3, c = 'size', cmap = 'coolwarm')
cbar = plt.colorbar()
cbar.set_label('size')

# %% [markdown]
# **boxplots**

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 11. Make a box plot of total_bill column

# %%
# CODE HERE

plt.boxplot(tips.total_bill, labels=['total_bill']);

# %%
tips.boxplot(column="total_bill")
# Out:
# <AxesSubplot:>

# %%
# Out:
# <AxesSubplot:>

# %%
# CODE HERE
sns.boxplot(y='total_bill', data= tips)
# Out:
# <AxesSubplot:ylabel='total_bill'>

# %%
# Out:
# <AxesSubplot:ylabel='total_bill'>

# %% [markdown]
# # 12. Seperate the the boxplot above using size columns

# %%
# CODE HERE
tips.boxplot(column="total_bill", by="size");

# %%
tips.boxplot(column="total_bill", by="size");

# %% [markdown]
# # 13. Make the same plot using seaborn

# %%
# CODE HERE
sns.boxplot(x='size', y= 'total_bill', data=tips);

# %% [markdown]
# # 14. Make a violinplot instead of boxplot and discuss the difference between boxplot and violinplot

# %%
# CODE HERE
sns.violinplot(x='size', y= 'total_bill', data=tips);
